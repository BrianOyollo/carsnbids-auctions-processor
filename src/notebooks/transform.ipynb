# %% [markdown]
# # Car&Bids Data Transformation

# %%
import json
import re
import pandas as pd
import os

# %% [markdown]
# ## Read auction files
# This is for development only

# %%
raw_auctions_path = ""
processed_auctions_path = ""

auction_files = os.listdir(raw_auctions_path)
auction_files
# Out:
# ['2025-03-12.json',
#  '2025-03-20.json',
#  '2024-12-05.json',
#  '2025-03-11.json',
#  '2023-08-24.json',
#  '2024-11-11.json',
#  '2025-05-31.json',
#  '2024-08-01_chunk601_to_700.json',
#  '2024-07-28_chunk301_to_400.json',
#  '2023-09-19.json',
#  '2023-08-08.json',
#  '2024-11-20.json',
#  '2025-05-09.json',
#  '2024-02-26.json',
#  '2023-06-19.json',
#  '2024-07-07_chunk101_to_200c.json',
#  '2024-03-19.json',
#  '2024-02-14.json',
#  '2024-10-14.json',
#  '2025-01-28.json',
#  '2024-08-04_chunk1_to_100.json',
#  '2025-03-19.json',
#  '2023-10-16.json',
#  '2023-09-26.json',
#  '2024-12-30.json',
#  '2024-08-15.json',
#  '2024-12-11.json',
#  '2024-07-28_chunk901_to_1000.json',
#  '2024-01-18.json',
#  '2023-06-05.json',
#  'auctions1-1000_1.json',
#  'auctions_c500s_501-1000_1.json',
#  '2023-04-03.json',
#  '2024-07-24.json',
#  '2023-07-31.json',
#  '2025-01-30.json',
#  '2024-07-05_chunk401_to_500b.json',
#  '2024-07-05_chunk801_to_900b.json',
#  '2024-07-28_chunk501_to_600.json',
#  '2023-07-10.json',
#  '2024-08-01_chunk1101_to_1200.json',
#  '2024-01-01.json',
#  '2024-11-15.json',
#  '2024-07-31_chunk901_to_1000.json',
#  '2025-02-03.json',
#  '2025-04-08.json',
#  'rescraped_results_1749230086.json',
#  '2024-07-09.json',
#  '2024-03-27.json',
#  '2024-07-16.json',
#  'auctions_c500s_1001-1500_1.json',
#  '2023-11-17.json',
#  '2024-07-31_chunk301_to_400.json',
#  '2024-03-18.json',
#  '2023-12-22.json',
#  '2025-04-22.json',
#  '2023-04-12.json',
#  '2024-12-31.json',
#  '2024-01-24.json',
#  '2023-06-28.json',
#  '2025-04-16.json',
#  '2024-02-23.json',
#  '2024-12-07.json',
#  '2025-05-06.json',
#  '2025-02-18.json',
#  '2024-07-31_chunk801_to_900.json',
#  '2024-10-23.json',
#  '2025-05-21.json',
#  '2023-04-25.json',
#  '2024-08-13.json',
#  '2023-06-21.json',
#  '2025-04-25.json',
#  '2024-12-13.json',
#  '2023-05-30.json',
#  '2023-10-05.json',
#  '2023-06-01.json',
#  '2024-03-12.json',
#  'rescraped_results_1749141856.json',
#  '2023-11-16.json',
#  '2025-04-07.json',
#  '2023-11-13.json',
#  '2024-08-30.json',
#  '2023-06-16.json',
#  '2025-04-14.json',
#  '2024-07-05_chunk601_to_700b.json',
#  '2024-07-23.json',
#  '2023-08-09.json',
#  '2024-08-01_chunk501_to_600.json',
#  '2024-07-28_chunk1201_to_1300.json',
#  'rescraped_results_1749221234.json',
#  '2025-01-22.json',
#  '2024-07-05_chunk101_to_200b.json',
#  '2024-07-28_chunk401_to_500.json',
#  '2024-02-21.json',
#  'auctions_2025-06-13.json',
#  '2024-07-19.json',
#  '2023-08-23.json',
#  '2025-02-13.json',
#  '2024-01-17.json',
#  '2023-09-28.json',
#  '2025-03-03.json',
#  '2024-08-01_chunk901_to_1000.json',
#  '2024-07-28_chunk1301_to_1400.json',
#  '2024-10-22.json',
#  '2024-12-02.json',
#  '2024-03-15.json',
#  '2024-07-31_chunk1_to_100.json',
#  '2024-01-10.json',
#  '2024-07-30_chunk1_to_100.json',
#  '2024-07-17.json',
#  '2024-12-20.json',
#  '2024-07-28_chunk1_to_100.json',
#  '2023-08-30.json',
#  '2024-08-01_chunk801_to_900.json',
#  '2023-07-18.json',
#  '2024-01-25.json',
#  '2023-09-29.json',
#  '2025-05-14.json',
#  '2025-02-14.json',
#  '2024-07-07_chunk1_to_100c.json',
#  '2023-09-05.json',
#  '2024-12-23.json',
#  '2024-08-01_chunk701_to_800.json',
#  '2024-07-28_chunk1001_to_1100.json',
#  '2025-04-29.json',
#  '2023-12-11.json',
#  '2023-07-24.json',
#  '2023-10-06.json',
#  '2023-10-25.json',
#  '2024-09-05.json',
#  '2024-01-30.json',
#  '2023-10-30.json',
#  '2023-06-30.json',
#  '2023-06-09.json',
#  '2024-08-19.json',
#  '2025-04-28.json',
#  '2023-07-26.json',
#  '2023-08-07.json',
#  '2024-11-04.json',
#  '2023-09-20.json',
#  '2024-11-27.json',
#  '2024-07-29_chunk1_to_100.json',
#  '2023-08-28.json',
#  '2023-08-14.json',
#  '2025-02-11.json',
#  '2023-07-28.json',
#  '2024-08-01_chunk401_to_500.json',
#  '2024-12-26.json',
#  '2024-01-31.json',
#  '2025-03-31.json',
#  '2023-08-02.json',
#  '2024-03-08.json',
#  '2024-07-03.json',
#  '2024-01-12.json',
#  '2024-09-26.json',
#  '2024-07-30_chunk701_to_800.json',
#  '2024-10-15.json',
#  '2025-06-03.json',
#  '2024-07-30_chunk801_to_900.json',
#  '2024-08-06.json',
#  '2023-03-21.json',
#  '2024-07-28_chunk1101_to_1200.json',
#  '2025-01-10.json',
#  '2024-07-01.json',
#  '2024-09-17.json',
#  '2024-02-06.json',
#  '2024-07-31_chunk201_to_300.json',
#  '2024-09-19.json',
#  '2024-07-22.json',
#  '2024-07-25.json',
#  '2023-06-02.json',
#  '2024-07-29_chunk301_to_400.json',
#  '2025-05-29.json',
#  '2024-07-03_chunk300_to_400.json',
#  '2024-10-01.json',
#  '2024-03-26.json',
#  '2024-01-16.json',
#  'auctions_rs_1749293942.json',
#  '2025-04-15.json',
#  '2024-10-09.json',
#  '2023-05-24.json',
#  '2023-11-09.json',
#  '2023-03-25.json',
#  '2023-06-22.json',
#  '2025-05-05.json',
#  '2025-02-24.json',
#  '2023-09-22.json',
#  '2024-10-03.json',
#  '2024-08-05.json',
#  '2023-06-29.json',
#  '2024-07-14.json',
#  '2025-03-10.json',
#  '2023-09-13.json',
#  '2024-03-04.json',
#  '2024-11-12.json',
#  '2025-03-06.json',
#  '2023-04-06.json',
#  '2023-09-25.json',
#  '2023-10-27.json',
#  '2025-05-12.json',
#  '2023-12-05.json',
#  '2023-10-20.json',
#  '2025-04-03.json',
#  '2024-08-01_chunk1_to_100.json',
#  '2024-11-29.json',
#  '2024-11-08.json',
#  '2025-02-20.json',
#  '2025-01-17.json',
#  '2024-09-12.json',
#  '2024-02-28.json',
#  '2023-10-12.json',
#  '2025-05-02.json',
#  '2023-07-03.json',
#  '2023-12-08.json',
#  '2023-09-27.json',
#  '2024-12-03.json',
#  '2025-02-26.json',
#  '2025-01-27.json',
#  'auctions1001-2000_1.json',
#  '2023-09-07.json',
#  '2024-09-13.json',
#  '2024-07-31_chunk701_to_800.json',
#  '2024-02-01.json',
#  '2025-01-13.json',
#  '2025-01-09.json',
#  '2023-11-10.json',
#  '2024-01-29.json',
#  '2025-01-15.json',
#  '2024-01-23.json',
#  'auctions_rs_1749679604.json',
#  '2025-05-15.json',
#  'auctions_2025-06-11.json',
#  '2023-12-20.json',
#  '2025-01-29.json',
#  '2025-02-06.json',
#  '2024-12-17.json',
#  '2025-05-23.json',
#  '2023-12-04.json',
#  '2024-10-10.json',
#  '2024-08-28.json',
#  '2025-01-24.json',
#  '2025-02-07.json',
#  '2024-02-12.json',
#  '2023-05-22.json',
#  '2024-12-27.json',
#  '2023-12-13.json',
#  'rescraped_results_1749203414.json',
#  '2023-06-23.json',
#  '2025-01-02.json',
#  '2025-05-07.json',
#  '2023-10-17.json',
#  '2024-07-08.json',
#  '2025-01-03.json',
#  'auctions_rs_1749679468.json',
#  '2024-07-30.json',
#  '2023-07-14.json',
#  '2023-12-27.json',
#  '2024-03-01.json',
#  '2024-07-28_chunk101_to_200.json',
#  '2024-03-13.json',
#  '2024-08-01_chunk301_to_400.json',
#  '2024-09-20.json',
#  '2023-07-05.json',
#  '2025-03-24.json',
#  '2024-07-03_chunk0_to_100.json',
#  '2024-09-09.json',
#  '2024-07-30_chunk501_to_600.json',
#  '2025-04-21.json',
#  '2024-08-27.json',
#  '2023-07-07.json',
#  '2025-01-21.json',
#  '2024-08-01_chunk1301_to_1400.json',
#  '2023-08-17.json',
#  '2025-04-04.json',
#  '2024-12-09.json',
#  '2024-08-22.json',
#  '2023-11-22.json',
#  '2023-08-22.json',
#  '2025-04-23.json',
#  '2024-10-29.json',
#  '2024-07-05_chunk1201_to_1300b.json',
#  '2023-06-07.json',
#  '2024-07-05_chunk701_to_800b.json',
#  '2024-02-29.json',
#  'auctions_2025-06-07.json',
#  '2023-10-23.json',
#  '2025-01-08.json',
#  '2023-06-12.json',
#  '2024-09-06.json',
#  '2023-10-18.json',
#  '2025-02-12.json',
#  '2025-04-17.json',
#  '2024-11-07.json',
#  '2025-02-28.json',
#  '2024-10-30.json',
#  '2023-04-05.json',
#  '2024-09-03.json',
#  '2023-10-10.json',
#  '2024-07-28_chunk601_to_700.json',
#  '2024-01-02.json',
#  '2025-02-05.json',
#  '2024-07-28_chunk701_to_800.json',
#  '2023-07-20.json',
#  '2023-08-16.json',
#  '2023-04-13.json',
#  '2023-10-11.json',
#  '2023-07-19.json',
#  '2024-02-19.json',
#  '2024-07-03_chunk400_to_500.json',
#  '2024-08-01.json',
#  '2024-07-30_chunk301_to_400.json',
#  '2024-11-25.json',
#  '2024-03-28.json',
#  'auctions_c500s_1-500_1.json',
#  '2023-06-08.json',
#  '2023-11-03.json',
#  '2023-10-31.json',
#  '2023-09-12.json',
#  '2024-10-02.json',
#  '2024-07-26.json',
#  '2024-11-13.json',
#  '2025-03-18.json',
#  '2023-09-15.json',
#  '2024-07-05_chunk301_to_400b.json',
#  '2024-03-14.json',
#  '2024-12-16.json',
#  '2023-10-02.json',
#  '2024-12-04.json',
#  '2023-07-12.json',
#  '2024-07-30_chunk201_to_300.json',
#  '2023-06-06.json',
#  '2024-01-11.json',
#  '2025-03-25.json',
#  '2024-02-09.json',
#  '2024-12-18.json',
#  '2023-11-29.json',
#  '2024-03-06.json',
#  '2024-11-19.json',
#  '2024-07-31_chunk401_to_500.json',
#  '2023-06-13.json',
#  '2024-10-31.json',
#  '2023-05-16.json',
#  '2023-11-02.json',
#  '2023-10-13.json',
#  '2024-07-05_chunk1001_to_1100b.json',
#  '2023-11-28.json',
#  '2025-02-27.json',
#  '2024-10-04.json',
#  '2024-02-13.json',
#  '2023-11-20.json',
#  '2023-12-19.json',
#  '2023-06-14.json',
#  'auctions3001-4000_1.json',
#  '2023-05-26.json',
#  '2024-02-20.json',
#  '2025-03-13.json',
#  '2025-05-01.json',
#  '2023-05-21.json',
#  '2025-02-04.json',
#  '2024-07-31_chunk601_to_700.json',
#  '2024-07-30_chunk401_to_500.json',
#  '2023-10-04.json',
#  '2023-12-15.json',
#  '2025-05-27.json',
#  '2024-07-05_chunk501_to_600b.json',
#  '2024-10-16.json',
#  '2024-08-01_chunk1001_to_1100.json',
#  '2024-12-06.json',
#  '2024-07-30_chunk901_to_1000.json',
#  '2023-05-04.json',
#  '2024-02-15.json',
#  '2024-10-25.json',
#  '2025-04-09.json',
#  '2024-11-18.json',
#  '2023-08-03.json',
#  '2024-07-05_chunk1101_to_1200b.json',
#  '2024-09-04.json',
#  '2023-12-09.json',
#  '2024-11-01.json',
#  '2025-01-25.json',
#  '2024-12-10.json',
#  '2023-04-19.json',
#  'auctions_2025-06-10.json',
#  '2025-05-20.json',
#  '2023-08-21.json',
#  '2023-10-19.json',
#  '2024-08-23.json',
#  '2024-08-12.json',
#  '2025-01-16.json',
#  '2024-10-28.json',
#  '2024-11-26.json',
#  '2024-02-16.json',
#  '2023-10-26.json',
#  '2024-10-21.json',
#  '2023-07-27.json',
#  '2023-08-04.json',
#  '2023-12-18.json',
#  '2025-06-06.json',
#  '2025-03-28.json',
#  '2024-10-08.json',
#  '2024-07-28_chunk801_to_900.json',
#  '2023-11-24.json',
#  '2024-01-22.json',
#  '2024-07-31_chunk101_to_200.json',
#  '2023-08-15.json',
#  '2023-11-08.json',
#  '2023-11-30.json',
#  '2024-08-08.json',
#  '2024-08-14.json',
#  '2024-08-07.json',
#  '2024-07-29.json',
#  '2023-07-13.json',
#  '2023-05-25.json',
#  '2024-08-21.json',
#  '2024-10-07.json',
#  '2025-03-07.json',
#  '2024-02-27.json',
#  '2024-12-12.json',
#  '2023-09-06.json',
#  '2024-07-30_chunk101_to_200.json',
#  '2024-02-05.json',
#  '2024-08-20.json',
#  'rescraped_results_1749237264.json',
#  '2024-07-03_chunk200_to_300.json',
#  '2024-03-21.json',
#  '2024-02-08.json',
#  '2023-05-31.json',
#  '2024-07-29_chunk201_to_300.json',
#  '2024-08-09.json',
#  '2023-09-14.json',
#  '2025-04-18.json',
#  '2025-01-31.json',
#  '2025-06-02.json',
#  '2023-09-08.json',
#  '2024-01-03.json',
#  '2024-10-11.json',
#  '2025-01-23.json',
#  '2024-11-14.json',
#  '2025-03-05.json',
#  '2025-04-11.json',
#  '2023-07-25.json',
#  '2024-11-21.json',
#  '2023-08-10.json',
#  '2025-05-16.json',
#  '2024-07-10.json',
#  'auctions_c500s_1501-2000_1.json',
#  '2024-09-30.json',
#  '2024-08-01_chunk1201_to_1300.json',
#  '2024-08-16.json',
#  '2023-10-03.json',
#  '2024-09-11.json',
#  'auctions2001-3000_1.json',
#  '2024-01-09.json',
#  '2025-05-13.json',
#  '2023-12-07.json',
#  '2024-07-30_chunk601_to_700.json',
#  '2025-05-28.json',
#  '2024-07-05_chunk201_to_300b.json',
#  '2025-03-26.json',
#  '2025-02-21.json',
#  '2024-01-26.json',
#  '2025-01-14.json',
#  'auctions_rs_1749679442.json',
#  '2024-03-25.json',
#  '2024-01-04.json',
#  '2024-10-18.json',
#  '2023-07-17.json',
#  '2023-12-12.json',
#  '2024-03-11.json',
#  '2023-06-15.json',
#  '2024-09-10.json',
#  '2024-09-27.json',
#  '2023-11-27.json',
#  '2024-10-17.json',
#  '2024-03-22.json',
#  '2023-12-21.json',
#  '2025-03-27.json',
#  '2024-09-24.json',
#  '2024-11-05.json',
#  '2023-12-01.json',
#  '2024-07-29_chunk401_to_500.json',
#  '2024-02-02.json',
#  '2025-02-19.json',
#  '2024-11-22.json',
#  '2025-04-02.json',
#  '2023-08-31.json',
#  '2025-04-10.json',
#  '2023-11-07.json',
#  '2025-05-08.json',
#  '2025-05-22.json',
#  'auctions_2025-06-12.json',
#  '2023-10-09.json',
#  '2025-06-04.json',
#  '2023-09-01.json',
#  '2024-09-18.json',
#  '2023-07-21.json',
#  '2023-08-01.json',
#  '2024-07-12.json',
#  '2023-11-14.json',
#  '2025-04-30.json',
#  '2023-10-24.json',
#  '2024-02-22.json',
#  '2025-01-07.json',
#  '2023-06-27.json',
#  '2023-12-06.json',
#  '2023-11-21.json',
#  'rescraped_results_1749211730.json',
#  '2025-04-24.json',
#  '2023-07-06.json',
#  '2024-03-29.json',
#  '2024-03-05.json',
#  '2025-05-19.json',
#  '2024-09-25.json',
#  '2024-07-05_chunk1_to_100b.json',
#  '2024-07-18.json',
#  '2023-12-14.json',
#  '2023-06-20.json',
#  '2025-06-05.json',
#  '2024-01-05.json',
#  '2024-02-07.json',
#  '2024-07-15.json',
#  '2024-07-05_chunk901_to_1000b.json',
#  '2024-09-16.json',
#  '2023-08-18.json',
#  '2024-07-31.json',
#  '2023-11-06.json',
#  '2025-02-17.json',
#  '2024-07-28_chunk201_to_300.json',
#  '2023-08-29.json',
#  '2024-01-19.json',
#  '2025-02-10.json',
#  '2023-09-21.json',
#  '2025-01-06.json',
#  '2025-03-17.json',
#  '2023-09-11.json',
#  '2024-08-02.json',
#  '2023-08-25.json',
#  '2024-09-23.json',
#  '2023-09-18.json',
#  '2023-08-11.json',
#  '2023-06-26.json',
#  '2024-08-29.json',
#  '2024-08-01_chunk201_to_300.json',
#  '2024-03-20.json',
#  '2024-07-31_chunk501_to_600.json',
#  '2024-10-24.json',
#  '2023-11-01.json',
#  '2023-03-18.json',
#  '2023-05-23.json',
#  '2025-03-21.json',
#  '2025-02-25.json',
#  '2024-01-08.json',
#  '2024-07-03_chunk100_to_200.json',
#  '2023-04-23.json',
#  '2024-07-02.json',
#  '2024-08-01_chunk101_to_200.json',
#  '2025-03-04.json',
#  '2024-07-11.json',
#  '2025-03-14.json',
#  '2023-11-15.json',
#  '2024-07-29_chunk101_to_200.json']

# %%
def convert_to_list_dicts(data) -> list:
    """
    Converts nested auction data to flat dictionaries, handling special list fields.
    
    Args:
        data: Input auction data (dict or list format)
            - If dict: {url: {auction_data}}
            - If list: [{auction_data}]
            
    Returns:
        list: Flattened auction records with consistent structure
    """
    
    def extract_list_field(field_data, list_key=None):
        """Extracts list from field data with flexible key handling"""
        if field_data is None:
            return []
        if isinstance(field_data, list):
            return field_data
        if isinstance(field_data, dict):
            if list_key:
                return field_data.get(list_key, [])
        return []

    def process_auction(auction, url=None):
        """Process individual auction record"""

        auction_stats = auction.get('auction_stats', {}) or {}
        auction_stats.setdefault('view_count', 0)
        auction_stats.setdefault('watcher_count', 0)
        
        auction_data = {
            "auction_url": url if url else auction.get('auction_url'),
            "auction_title": auction.get('auction_title'),
            "auction_subtitle": auction.get('auction_subtitle'),
            "dougs_take": auction.get('dougs_take'),
            "auction_highlights": extract_list_field(
                auction.get('auction_highlights'), 
                list_key='bullet_points'
            ),
            "services": extract_list_field(
                auction.get('services') or auction.get('service_history'),
                list_key='items'
            ),
            "auction_equipment": auction.get('auction_equipment'),
            "modifications": auction.get('modifications'),
            "known_flaws": auction.get('known_flaws'),
            "included_items": auction.get('included_items'),
            "ownership_history": auction.get('ownership_history'),
            "seller_notes": auction.get('seller_notes'),
            "auction_videos":auction.get('auction_videos',[]),
            **auction.get('auction_quick_facts', {}),
            **auction_stats,
        }
        return auction_data


    # Handle input types
    if isinstance(data, dict):
        return [process_auction(data[auction], auction) for auction in data]
    if isinstance(data, list):
        return [process_auction(auction) for auction in data]
    raise ValueError("Input must be dictionary or list")

# %%
def read_auction_file(filename):
    with open(f'{raw_auctions_path}/{filename}') as file:
        data = json.load(file)
    return data

# %%
auction_data = []
for file in auction_files:
    data = read_auction_file(file)
    auction_data.extend(convert_to_list_dicts(data))

auction_data[:5]
# Out:
# [{'auction_url': 'https://carsandbids.com/auctions/3Lj5agnZ/2019-rolls-royce-ghost',
#   'auction_title': '2019 Rolls-Royce Ghost',
#   'auction_subtitle': '~12,300 Miles, Twin-Turbo V12 Power, Western-Owned, Unmodified',
#   'dougs_take': "The Rolls-Royce Ghost is, without a doubt, one of the most impressive luxury cars around. Not only does this example feature gorgeous styling and an opulent interior, it's also equipped with a powerful twin-turbocharged V12 that's good for 563 horsepower. Other factory equipment includes 21-inch alloy wheels, self-righting wheel center caps, self-leveling air suspension, heated and cooled front seats, heated rear seats, a Shooting Star headliner, 4-zone automatic climate control, and adaptive cruise control. This Ghost also touts low mileage, no modifications, and ownership in Western states since new, for added peace of mind. Plus, this Ghost comes with a clean, accident-free Carfax report, which always increases the appeal.",
#   'auction_highlights': ['The odometer on this Ghost currently displays approximately 12,300 miles.',
#    'The attached Carfax vehicle history report shows no accidents or mileage discrepancies in this Ghost’s past. It also shows that this Rolls-Royce has been registered in California and Oregon since new.',
#    'Factory equipment includes 21-inch alloy wheels, self-righting wheel center caps, self-leveling air suspension, an electrically-retracting Spirit of Ectasy emblem, power-adjustable, heated, and cooled front seats, heated rear seats, a Shooting Star headliner, 4-zone automatic climate control, adaptive cruise control, and more, as outlined below. The selling dealer reports no modifications.',
#    "Rolls-Royce released the BMW 7 Series-derived Ghost for 2011 as its entry-level sedan, and it launched the Extended Wheelbase (EWB) model the following year. While it was cheaper and smaller than the Phantom, the Ghost nonetheless stood proud as one of the world's most luxurious cars by offering a long list of features and a correspondingly high price tag. Production ended in 2020.",
#    'Power comes from a 6.6-liter twin-turbocharged V12 engine, rated at 563 horsepower and 605 lb-ft of torque. Output is sent to the rear wheels via an 8-speed automatic transmission.'],
#   'services': ['2025: Engine oil and filter changed'],
#   'auction_equipment': ['21-inch alloy wheels',
#    'Self-righting wheel center caps',
#    'Self-leveling air suspension',
#    'Electrically-retracting Spirit of Ectasy emblem',
#    'Comfort Access',
#    'Soft-close doors',
#    'Power-closing assistance for rear doors',
#    'Leather upholstery',
#    'Wood interior trim',
#    'Power-adjustable, heated, and cooled front seats',
#    'Heated rear seats',
#    'Shooting Star headliner',
#    'Lambswool floor mats',
#    '4-zone automatic climate control',
#    '10.2-inch infotainment display',
#    'Navigation system',
#    'Front and rear Park Distance Control',
#    'Rearview camera',
#    'Adaptive cruise control'],
#   'modifications': [],
#   'known_flaws': ['Scuffs on bottom of bumper',
#    'Some wear on front seat bolsters, interior surfaces and touchpoints'],
#   'included_items': ['1 key'],
#   'ownership_history': 'The selling dealer acquired this Ghost in January 2025.',
#   'seller_notes': None,
#   'auction_videos': [],
#   'Make': 'Rolls-Royce',
#   'Model': 'Ghost\nSave',
#   'Mileage': '12,300',
#   'VIN': 'SCA664S57KUX54721',
#   'Title Status': 'Clean (CA)',
#   'Location': 'Tualatin, OR 97062',
#   'Seller': 'Lamboman3',
#   'Engine': '6.6L Turbocharged V12',
#   'Drivetrain': 'Rear-wheel drive',
#   'Transmission': 'Automatic (8-Speed)',
#   'Body Style': 'Sedan',
#   'Exterior Color': 'English White',
#   'Interior Color': 'Navy Blue',
#   'Seller Type': 'Dealer',
#   'reserve_status': 'Reserve',
#   'auction_status': 'Reserve not met, bid to',
#   'highest_bid_value': '$139,000',
#   'auction_date': 'Mar 12, 2025 8:19 PM UTC',
#   'view_count': '12,107',
#   'bid_count': '31',
#   'bids': ['$139,000',
#    '$138,500',
#    '$138,000',
#    '$137,500',
#    '$137,000',
#    '$136,500',
#    '$136,000',
#    '$135,500',
#    '$135,000',
#    '$134,500',
#    '$134,000',
#    '$133,500',
#    '$133,000',
#    '$132,500',
#    '$132,000',
#    '$131,500',
#    '$131,000',
#    '$130,500',
#    '$130,000',
#    '$129,500',
#    '$129,000',
#    '$128,500',
#    '$128,000',
#    '$127,500',
#    '$127,000',
#    '$126,000',
#    '$125,000',
#    '$100,500',
#    '$100,000',
#    '$50,000',
#    '$5,000'],
#   'watcher_count': 0},
#  {'auction_url': 'https://carsandbids.com/auctions/36WZplWn/1983-toyota-land-cruiser-fire-truck',
#   'auction_title': '1983 Toyota Land Cruiser Fire Truck',
#   'auction_subtitle': 'NO RESERVE ~10,700 Miles, Japanese-Market Fire Truck, 4-Speed Manual, 4WD, U.S. Title',
#   'dougs_take': "Now THIS is really cool! The 60-Series Toyota Land Cruiser is a wonderful SUV – it's a lot more basic and utilitarian than the 80-Series trucks that were sold in the 1990s, and its boxy styling is quickly becoming iconic. This particular 60-Series Land Cruiser is especially interesting, as it's a right-hand drive model from Japan that's been converted into a fire truck! It features the neat firefighting gear in the rear section along with open-air rear seating, and it touts very low mileage. It also comes with a U.S. title – so the difficult (and time-consuming) process of importing an SUV from abroad has already been completed. Plus, this Land Cruiser fire truck is offered with the added excitement of no reserve!",
#   'auction_highlights': ["This is a right-hand drive, Japanese-market truck that's titled in Mississippi. It's equipped with a metric instrument cluster and its odometer displays about 17,200 kilometers, which represents approximately 10,700 miles.",
#    'This Land Cruiser was reportedly converted into a fire truck in Japan, and it features fire-fighting equipment, 15-inch wheels, a red exterior, fender-mounted mirrors, CARR side steps, open-air rear seating with storage compartment, diamond-plated rear areas, mudflaps, engine oil temperature gauge, and aftermarket cupholders.',
#    'Released globally in 1980, the 60-Series Land Cruiser was shaped by the growing popularity of SUVs -- drivers increasingly wanted a 4x4 that could take their whole family on a trip. It was consequently bigger and far more comfort-oriented than the 50-Series model it was designed to replace and it was available with a longer list of features. In a way, the 60 bridges the gap between the relatively rudimentary Land Cruiser variants (like the earlier 40s) and the more luxurious versions that came later (such as the 80).',
#    'Power comes from a carbureted 4.2-liter straight-6, rated at about 135 horsepower and 210 lb-ft of torque. It spins the rear or the four wheels via a 4-speed manual transmission and a 2-speed transfer case.'],
#   'services': ['2024: Engine oil and filter changed'],
#   'auction_equipment': ['Vinyl and cloth upholstery', 'Manual windows'],
#   'modifications': ['Fire-fighting equipment (lights, siren, PA system, water pump, interior switches)',
#    '15-inch wheels',
#    'Exterior painted red',
#    'Fender-mounted mirrors',
#    'CARR side steps',
#    'Open-air rear seating with storage compartment',
#    'Diamond-plated rear areas',
#    'Mudflaps',
#    'Engine oil temperature gauge',
#    'Aftermarket cupholders'],
#   'known_flaws': ['Some chips and scratches around the exterior',
#    'Some spider cracks on hood',
#    "Wear on upholstery; tear in driver's seat",
#    'Stains in headliner',
#    'Some corrosion on exhaust components',
#    'The seller reports the engine and fire pump seep fluid.'],
#   'included_items': ['2 keys',
#    'Service record',
#    'Red wheels with tires (tires dry-rotted)'],
#   'ownership_history': 'The seller purchased this Toyota in October 2015 and has added approximately 9,000 miles since.',
#   'seller_notes': None,
#   'auction_videos': [],
#   'Make': 'Toyota',
#   'Model': 'Land Cruiser\nSave',
#   'Mileage': '10,700',
#   'VIN': 'FJ61000522',
#   'Title Status': 'Clean (MS)',
#   'Location': 'Scottsboro, AL 35769',
#   'Seller': 'fj75',
#   'Engine': '4.2L I6',
#   'Drivetrain': '4WD/AWD',
#   'Transmission': 'Manual (4-Speed)',
#   'Body Style': 'SUV/Crossover',
#   'Exterior Color': 'Red',
#   'Interior Color': 'Brown/Beige',
#   'Seller Type': 'Private Party',
#   'reserve_status': 'No reserve',
#   'auction_status': 'Sold to',
#   'highest_bid_value': '$10,499',
#   'auction_date': 'Mar 12, 2025 8:12 PM UTC',
#   'view_count': '8,320',
#   'bid_count': '18',
#   'bids': ['$10,499',
#    '$10,200',
#    '$10,099',
#    '$9,999',
#    '$9,600',
#    '$9,500',
#    '$9,100',
#    '$9,000',
#    '$8,300',
#    '$8,100',
#    '$7,600',
#    '$7,500',
#    '$7,200',
#    '$7,100',
#    '$5,000',
#    '$4,000',
#    '$200',
#    '$100'],
#   'watcher_count': 0},
#  {'auction_url': 'https://carsandbids.com/auctions/KDyGoeqp/2012-bmw-m3-coupe-competition-package',
#   'auction_title': '2012 BMW M3 Coupe Competition Package',
#   'auction_subtitle': '6-Speed Manual, V8 Power, Fox Red Interior, Some Modifications',
#   'dougs_take': "The E92 BMW M3 is an exciting car, as it's the only time BMW put a high-revving, naturally-aspirated V8 in an M3 – and it will undoubtedly never happen again. This particular M3 features a gorgeous Fox Red interior along with a 6-speed manual transmission. It also boasts some great upgrades like a Turner Motorsport Stage 2 93 octane tune, a Macht Schnell intake, and a Ground Control coilover conversion kit with Eibach springs and Koni shocks. Plus, this M3 comes with a clean, accident-free Carfax report that shows mostly warm-climate Florida ownership, which is a great benefit.",
#   'auction_highlights': ['This BMW is equipped with a 6-speed manual transmission.',
#    "The attached Carfax history report shows no accidents or mileage discrepancies in this BMW's past. It also shows ownership primarily in Florida.",
#    'According to the build sheet provided in the gallery, factory equipment includes the Competition and Premium packages, a limited-slip differential, Electronic Damper Control, adaptive xenon headlights, Novillo leather upholstery, heated front sport seats, an Individual sound system, and more as detailed below.',
#    'Modifications reported by the seller include a Turner Motorsport Stage 2 93 octane tune, a Macht Schnell intake, a modification of the factory exhaust, BE Bearings rod bearings, ARP rod bolts, aftermarket test pipes, a Ground Control coilover conversion kit with Eibach springs and Koni shocks, stainless steel brake lines, wheels powder-coated in black, tinted windows, and an F10 BMW M5 shift knob.',
#    "BMW engineers had to balance horsepower and weight as they developed the first and only M3 equipped with a V8 engine. Released for 2008, and based on the E90-generation 3 Series, it won over skeptical enthusiasts by offering performance that approached supercar levels in a practical, daily-drivable, and relatively subtle package. Sedan, coupe, and convertible variants were offered. The Competition Package also includes a sport exhaust system and a unique rear spoiler, which add to the car's already impressive performance and aerodynamics.",
#    'Power comes from an S65 4.0-liter V8, rated at 414 horsepower and 295 lb-ft of torque. Due to the modifications performed to this M3, it likely produces more power, but a dyno sheet was not provided to confirm. Output is sent to the rear wheels via a 6-speed manual transmission.'],
#   'services': ['February 2025: Engine oil and filter changed, fuel door popper repaired',
#    'March 2024: Engine oil and filter changed, oil filler cap replaced',
#    'December 2023: Expansion tank, cap and vent lines replaced, brake fluid flushed, coolant bled',
#    'March 2023: A/C refrigerant recharged, cabin air filters and key fob battery replaced, engine oil and filter changed',
#    'February 2022: CAS module and hood shocks replaced',
#    'October 2021: Front and rear brake pads and rotors and battery replaced, brake fluid flushed'],
#   'auction_equipment': ['Competition Package (19-inch Style 359M staggered-width alloy wheels, lowered adaptive suspension, revised Electric Damping Control system settings, re-tuned Dynamic Stability Control system)',
#    'Premium Package (power folding auto mirrors, universal garage door opener, Comfort Access keyless entry, power rear sunshade, power-adjustable front seats, interior mirror with compass, rear Park Distance Control, navigation system with RTTI)',
#    'Limited-slip differential',
#    'Electronic Damper Control (EDC)',
#    'Adaptive xenon headlights',
#    'Shadowline exterior trim',
#    'Novillo leather upholstery',
#    'Heated front sport seats',
#    'Carbon leather interior trim',
#    'Anthracite headliner',
#    'Individual sound system',
#    'Automatic climate control',
#    'Cruise control'],
#   'modifications': ['Turner Motorsport Stage 2 93 octane tune',
#    'Macht Schnell intake',
#    'Factory perforated exhaust pipes replaced with straight pipes',
#    'BE Bearings rod bearings',
#    'Macht Schnell underdrive pulley kit',
#    'ARP rod bolts',
#    'Aftermarket test pipes',
#    'Ground Control coilover conversion kit with Eibach springs and Koni shocks (retains factory suspension setting)',
#    'Wheel stud conversion',
#    'Stainless steel brake lines',
#    'Factory wheels powder-coated black',
#    'Tinted windows',
#    'F10 BMW M5 shift knob'],
#   'known_flaws': ['Chips, scuffs, and scratches around the exterior (pictured in the gallery)',
#    'Paint cracks on rear bumper',
#    'Blemish on trunk lip',
#    'Crazing on trunk badge',
#    'Curb rash on passenger-side wheels; rear tires carry 2019 date codes',
#    'Creases and wear on leather upholstery, steering wheel, and shift knob',
#    'Scuffs on some interior trim pieces',
#    'Sagging headliner',
#    'Stains in trunk carpet',
#    'The seller reports that the TPMS system is inoperable, the front coilovers make a rattling sound, and the rear center console roller cover is broken.',
#    'Service documentation from February 2025 indicates that the valve covers are leaking, and service documentation from March 2024 indicates that the TMPS light illuminates intermittently when driving.'],
#   'included_items': ['2 keys',
#    'Owner’s manuals',
#    'Service records',
#    '1 liter of engine oil',
#    '1 gallon BMW coolant',
#    'Engine air filter',
#    'Carbon fiber rear spoiler'],
#   'ownership_history': 'The seller purchased this M3 in October 2021 and has added approximately 12,100 miles since.',
#   'seller_notes': None,
#   'auction_videos': [],
#   'Make': 'BMW',
#   'Model': 'E9X M3\nSave',
#   'Mileage': '85,000',
#   'VIN': 'WBSKG9C54CE798308',
#   'Title Status': 'Clean (FL)',
#   'Location': 'Weston, FL 33326',
#   'Seller': 'MrSouvlaki',
#   'Engine': '4.0L V8',
#   'Drivetrain': 'Rear-wheel drive',
#   'Transmission': 'Manual (6-Speed)',
#   'Body Style': 'Coupe',
#   'Exterior Color': 'Space Grey Metallic',
#   'Interior Color': 'Fox Red/Black',
#   'Seller Type': 'Private Party',
#   'reserve_status': 'Reserve',
#   'auction_status': 'Sold to',
#   'highest_bid_value': '$23,750',
#   'auction_date': 'Mar 12, 2025 8:11 PM UTC',
#   'view_count': '13,722',
#   'bid_count': '53',
#   'bids': ['$23,750',
#    '$23,500',
#    '$23,000',
#    '$22,750',
#    '$22,500',
#    '$22,250',
#    '$22,000',
#    '$21,500',
#    '$21,250',
#    '$21,000',
#    '$20,750',
#    '$20,450',
#    '$20,200',
#    '$19,950',
#    '$19,700',
#    '$19,450',
#    '$19,200',
#    '$18,892',
#    '$18,000',
#    '$17,500',
#    '$16,500',
#    '$15,250',
#    '$15,000',
#    '$14,900',
#    '$14,800',
#    '$14,700',
#    '$14,600',
#    '$14,500',
#    '$14,400',
#    '$14,300',
#    '$14,100',
#    '$14,000',
#    '$13,750',
#    '$13,300',
#    '$13,200',
#    '$13,000',
#    '$12,500',
#    '$11,369',
#    '$11,200',
#    '$11,100',
#    '$11,000',
#    '$10,700',
#    '$10,600',
#    '$10,500',
#    '$10,000',
#    '$5,000',
#    '$3,000',
#    '$2,600',
#    '$2,500',
#    '$1,000',
#    '$492',
#    '$392',
#    '$100'],
#   'watcher_count': 0},
#  {'auction_url': 'https://carsandbids.com/auctions/98XjGMOQ/2008-porsche-cayman-s',
#   'auction_title': '2008 Porsche Cayman S',
#   'auction_subtitle': 'NO RESERVE 6-Speed Manual, Sport Chrono Package, Cocoa Interior, Mostly Unmodified',
#   'dougs_take': "I personally love the 987 Porsche Cayman, as it touts excellent handling, thrilling performance, and sleek styling that has aged well. This is the Cayman S, which boasts more power than the base Cayman, and it touts the 6-speed manual transmission that enhances the driving experience. It's also finished in a gorgeous color combination – and it's largely unmodified, which enhances the appeal. This Cayman isn't perfect, as it needs engine work – but it looks like a great option if you're in the market for a project car. This Cayman has also been mostly owned in warm-weather states – AND it's offered with no reserve, which always increases the appeal.",
#   'auction_highlights': ['This coupe is equipped with the desirable 6-speed manual transmission.',
#    'The attached Carfax history report shows that this Cayman has been mostly Georgia- and California-owned.',
#    'Factory equipment includes the Sport Chrono and Bose High End Sound packages, a speed-activated rear spoiler, heated front sport seats, painted seatbacks, and rain-sensing windshield wipers, according to a build sheet pictured in the gallery. Modifications reported by the seller include a Borla exhaust system, Bilstein parts in the suspension system, and a magnetic cell phone mount.',
#    "Porsche introduced the original Cayman as the Boxster's long-awaited coupe counterpart for the 2006 model year. Called 987 internally, it was more than merely a Boxster with a fixed top and a hatch, and about 20% of the parts used to build it were new. Some enthusiasts placed the Cayman's chassis above the 911 in the Porsche pecking order because it was nimble, quick, and extremely well-balanced.",
#    'Power comes from a 3.4-liter flat-6, rated at 295 horsepower and 251 lb-ft of torque. It spins the rear wheels via a 6-speed manual transmission.'],
#   'services': ['April 2022: Engine oil and filter changed'],
#   'auction_equipment': ['Sport Chrono Package without PCM (sport driving profile and stopwatch on the dashboard)',
#    'Bi-Xenon Headlamp Package (bi-xenon headlights)',
#    'Aluminum-Look Exterior Package (aluminum-look exterior trim)',
#    'Bose High End Sound Package (Bose sound system)',
#    '18-inch wheels',
#    'Fog lights',
#    'Speed-activated rear spoiler',
#    'Aluminum-look rear spoiler lip',
#    'Leather upholstery',
#    'Heated front sport seats',
#    'Painted seatbacks',
#    'Rain-sensing windshield wipers',
#    'Auto-dimming door mirrors',
#    'CD player'],
#   'modifications': ['Borla exhaust system',
#    'Bilstein parts in the suspension system',
#    'Wide-angle inserts in the door mirrors',
#    'Magnetic cell phone mount'],
#   'known_flaws': ['The seller states that cylinder #6 has "bore scoring" and that the engine consequently needs to be rebuilt or replaced. Please contact the seller directly for more details.',
#    'The attached Carfax history report notes that this Cayman was involved in a front impact in April 2010. It adds that this car was not damaged and that the airbags did not deploy.',
#    'Some exterior chips, scratches, dings, and paint imperfections',
#    'Cracked weatherstripping on the bottom part of the windshield',
#    '2016 date code on the tires',
#    'Wear on the upholstery and on some of the interior touch points',
#    'Sagging headliner',
#    'Scratches on the door sills and door panels',
#    'Engine oil filler cover latch broken',
#    "The front trunk release lever doesn't work (the front trunk needs to be opened with the key fob).",
#    'The seller states that the engine oil needs to be changed.'],
#   'included_items': ['1 key', "Owner's manuals"],
#   'ownership_history': 'The seller purchased this Cayman in 2022.',
#   'seller_notes': None,
#   'auction_videos': [],
#   'Make': 'Porsche',
#   'Model': '987 Cayman\nSave',
#   'Mileage': '86,900',
#   'VIN': 'WP0AB29828U781238',
#   'Title Status': 'Clean (OR)',
#   'Location': 'Eugene, OR 97404',
#   'Seller': 'focuts',
#   'Engine': '3.4L Flat-6',
#   'Drivetrain': 'Rear-wheel drive',
#   'Transmission': 'Manual (6-Speed)',
#   'Body Style': 'Coupe',
#   'Exterior Color': 'Carrara White',
#   'Interior Color': 'Cocoa',
#   'Seller Type': 'Private Party',
#   'reserve_status': 'No reserve',
#   'auction_status': 'Sold to',
#   'highest_bid_value': '$9,500',
#   'auction_date': 'Mar 12, 2025 8:00 PM UTC',
#   'view_count': '11,835',
#   'bid_count': '15',
#   'bids': ['$9,500',
#    '$9,100',
#    '$9,000',
#    '$8,100',
#    '$8,000',
#    '$7,200',
#    '$7,100',
#    '$7,000',
#    '$6,900',
#    '$4,500',
#    '$3,500',
#    '$3,250',
#    '$3,000',
#    '$1,986',
#    '$986'],
#   'watcher_count': 0},
#  {'auction_url': 'https://carsandbids.com/auctions/9e60821A/2014-bmw-m6-convertible',
#   'auction_title': '2014 BMW M6 Convertible',
#   'auction_subtitle': '6-Speed Manual, Twin-Turbo V8, San Marino Blue, Florida-Owned',
#   'dougs_take': 'The F12 BMW M6 Convertible is a thrilling blend of performance and luxury, boasting handsome styling, fantastic long-distance comfort, and a powerful twin-turbocharged V8 with 560 horsepower. This particular M6 Convertible is more desirable than most, as it touts the rare 6-speed manual transmission for an especially engaging driving experience. It also boasts some excellent factory equipment, including the Executive package, heated and ventilated front seats, carbon fiber interior trim, and much more. I really like the color combination here, too, as it looks great finished in San Marino Blue over an Amaro Brown leather interior. Plus, this M6 is offered with a clean, accident-free Carfax report, showing ownership in warm-climate Florida from new, for added bidder confidence.',
#   'auction_highlights': ['This M6 features the desirable 6-speed manual transmission. According to BMWMRegistry.com, this M6 Convertible is 1 of 80 produced with a manual transmission.',
#    "The attached Carfax history report shows no accidents or mileage discrepancies in this M6's past. It also confirms that it's been registered in Florida from new.",
#    'According to the build sheet provided in the gallery, factory equipment includes the Executive package, 19-inch Style 344 wheels, adaptive suspension, adaptive LED headlights, soft-close doors, leather upholstery, carbon fiber interior trim, power-adjustable heated and ventilated front seats, a navigation system, and more as listed below. The selling dealer reports no modifications.',
#    "BMW released the F12-and F13-generation 6 Series for the 2012 model year. Available as a coupe and as a convertible, the third-generation 6 Series was longer, lower, and wider than its predecessor, and stylists toned down its exterior design. The range-topping, high-performance M6 also released for 2012 swapped its predecessor's naturally-aspirated V10 for a twin-turbocharged V8 that BMW M presented as the most powerful engine it had ever fitted to a series-produced car. Production ended in 2018.",
#    'Power comes from a twin-turbocharged 4.4-liter V8, rated at 560 horsepower and 500 lb-ft of torque. Output is sent to the rear wheels via a 6-speed manual transmission.'],
#   'services': ['August 2024 (49,645 miles): Wiper(s) replaced',
#    'August 2023 (46,536 miles): Air filter, anti-theft/keyless remote battery, and cabin air filter replaced/cleaned, differential fluid flushed, engine oil and filter changed, one tire mounted and balanced, spark plug(s) cleaned, replaced, and gap adjusted',
#    'August 2022 (43,346 miles): Four tires mounted and balanced',
#    'July 2022 (42,872 miles): Brake fluid flushed, engine oil and filter changed',
#    'May 2020: Brake fluid flushed, cabin air filter replaced/cleaned, four wheel alignment performed, engine oil and filter changed, rear brake pads and rotors replaced, two tires mounted and balanced',
#    'Engine oil and filter changed',
#    'Clutch replaced'],
#   'auction_equipment': ['Executive Package (heated steering wheel, active ventilated front seats, head-up display, Bang & Olufsen surround sound system)',
#    '19-inch Style 344 alloy wheels',
#    'Adaptive suspension',
#    'Adaptive LED headlights',
#    'Power-retractable soft top',
#    'Soft-close doors',
#    'BMW Individual leather upholstery',
#    'Carbon fiber interior trim',
#    'Heated and power-adjustable front seats',
#    'Navigation system',
#    'Park Distance Control (PDC)',
#    'Rear-view camera',
#    'Comfort Access keyless entry system'],
#   'modifications': [],
#   'known_flaws': ['Rock chips on the front end',
#    "Scuffs on the front bumper's underside",
#    'Curb rash on wheels',
#    'Wear and some creases on the seats',
#    'Scuff marks and some wear on interior touch points'],
#   'included_items': ['2 keys', "Owner's manual"],
#   'ownership_history': 'The selling dealer acquired this M6 in January 2025 and reportedly added approximately 800 miles since.',
#   'seller_notes': None,
#   'auction_videos': [],
#   'Make': 'BMW',
#   'Model': 'F06/F12/F13 M6\nSave',
#   'Mileage': '51,300',
#   'VIN': 'WBSLZ9C58EDZ78690',
#   'Title Status': 'Clean (FL)',
#   'Location': 'Buford, GA 30518',
#   'Seller': 'orchidauto',
#   'Engine': '4.4L Turbocharged V8',
#   'Drivetrain': 'Rear-wheel drive',
#   'Transmission': 'Manual (6-Speed)',
#   'Body Style': 'Convertible',
#   'Exterior Color': 'San Marino Blue Metallic',
#   'Interior Color': 'Amaro Brown',
#   'Seller Type': 'Dealer',
#   'reserve_status': 'Reserve',
#   'auction_status': 'Sold to',
#   'highest_bid_value': '$42,000',
#   'auction_date': 'Mar 12, 2025 7:59 PM UTC',
#   'view_count': '12,166',
#   'bid_count': '39',
#   'bids': ['$42,000',
#    '$41,000',
#    '$40,500',
#    '$40,000',
#    '$39,750',
#    '$39,500',
#    '$39,250',
#    '$39,000',
#    '$38,500',
#    '$38,250',
#    '$38,000',
#    '$37,500',
#    '$37,000',
#    '$36,750',
#    '$36,500',
#    '$35,750',
#    '$35,406',
#    '$35,000',
#    '$34,000',
#    '$33,750',
#    '$33,500',
#    '$33,250',
#    '$33,000',
#    '$30,000',
#    '$29,000',
#    '$28,000',
#    '$27,000',
#    '$25,500',
#    '$25,000',
#    '$23,500',
#    '$23,250',
#    '$23,000',
#    '$22,475',
#    '$22,222',
#    '$20,000',
#    '$13,000',
#    '$9,000',
#    '$8,888',
#    '$1,000'],
#   'watcher_count': 0}]

# %% [markdown]
# ## Clean auction data

# %%
raw_df = pd.DataFrame(auction_data)
raw_df
# Out:
#                                              auction_url  \
# 0      https://carsandbids.com/auctions/3Lj5agnZ/2019...
# 1      https://carsandbids.com/auctions/36WZplWn/1983...
# 2      https://carsandbids.com/auctions/KDyGoeqp/2012...
# 3      https://carsandbids.com/auctions/98XjGMOQ/2008...
# 4      https://carsandbids.com/auctions/9e60821A/2014...
# ...                                                  ...
# 29602  https://carsandbids.com/auctions/rGBw6LXE/2019...
# 29603  https://carsandbids.com/auctions/3Lo0XjaX/2000...
# 29604  https://carsandbids.com/auctions/rN0W5jJb/1991...
# 29605  https://carsandbids.com/auctions/30w4j02g/2017...
# 29606  https://carsandbids.com/auctions/rJD7QWMw/1993...
#
#                                       auction_title  \
# 0                            2019 Rolls-Royce Ghost
# 1               1983 Toyota Land Cruiser Fire Truck
# 2             2012 BMW M3 Coupe Competition Package
# 3                             2008 Porsche Cayman S
# 4                           2014 BMW M6 Convertible
# ...                                             ...
# 29602                          2019 BMW 750i xDrive
# 29603                      2000 Mercedes-Benz SL500
# 29604  1991 Mitsubishi Delica Star Wagon Exceed 4WD
# 29605                        2017 BMW M6 Gran Coupe
# 29606                      1993 Toyota Land Cruiser
#
#                                         auction_subtitle  \
# 0      ~12,300 Miles, Twin-Turbo V12 Power, Western-O...
# 1      NO RESERVE ~10,700 Miles, Japanese-Market Fire...
# 2      6-Speed Manual, V8 Power, Fox Red Interior, So...
# 3      NO RESERVE 6-Speed Manual, Sport Chrono Packag...
# 4      6-Speed Manual, Twin-Turbo V8, San Marino Blue...
# ...                                                  ...
# 29602  Highly Optioned, M Sport Package, V8 Power, Mo...
# 29603  NO RESERVE 1 Owner Until 2022, California-Owne...
# 29604  Turbodiesel-Powered Japanese-Market Van, 4WD, ...
# 29605  Competition and Executive Packages, Unmodified...
# 29606  NO RESERVE Full-Time 4WD, Off-Road Modificatio...
#
#                                               dougs_take  \
# 0      The Rolls-Royce Ghost is, without a doubt, one...
# 1      Now THIS is really cool! The 60-Series Toyota ...
# 2      The E92 BMW M3 is an exciting car, as it's the...
# 3      I personally love the 987 Porsche Cayman, as i...
# 4      The F12 BMW M6 Convertible is a thrilling blen...
# ...                                                  ...
# 29602  The 750i xDrive is a LOT of car for the money ...
# 29603  The R129 SL is a modern classic Mercedes-Benz,...
# 29604  The Delica is hands-down one of the coolest va...
# 29605  The M6 Gran Coupe is an interesting alternativ...
# 29606  The 80-Series Toyota Land Cruiser boasts hands...
#
#                                       auction_highlights  \
# 0      [The odometer on this Ghost currently displays...
# 1      [This is a right-hand drive, Japanese-market t...
# 2      [This BMW is equipped with a 6-speed manual tr...
# 3      [This coupe is equipped with the desirable 6-s...
# 4      [This M6 features the desirable 6-speed manual...
# ...                                                  ...
# 29602  [The attached Carfax history report shows no a...
# 29603  [The odometer on this SL500 displays about 63,...
# 29604  [This Delica is a Japanese-spec, right-hand-dr...
# 29605  [The attached Carfax vehicle history report sh...
# 29606  [The attached Carfax history report contains s...
#
#                                                 services  \
# 0                  [2025: Engine oil and filter changed]
# 1                  [2024: Engine oil and filter changed]
# 2      [February 2025: Engine oil and filter changed,...
# 3            [April 2022: Engine oil and filter changed]
# 4      [August 2024 (49,645 miles): Wiper(s) replaced...
# ...                                                  ...
# 29602  [August 2022 (31,037 miles): Engine oil and fi...
# 29603                                                 []
# 29604  [August 2022 (83,000 kilometers/51,600 miles):...
# 29605  [May 2021 (31,615 miles): Engine oil and filte...
# 29606  [Front drive shaft and couplings replaced, Mas...
#
#                                        auction_equipment  \
# 0      [21-inch alloy wheels, Self-righting wheel cen...
# 1           [Vinyl and cloth upholstery, Manual windows]
# 2      [Competition Package (19-inch Style 359M stagg...
# 3      [Sport Chrono Package without PCM (sport drivi...
# 4      [Executive Package (heated steering wheel, act...
# ...                                                  ...
# 29602  [Luxury Rear Seating Package (rear ventilated ...
# 29603  [18-inch AMG wheels, Color-matched hardtop, Po...
# 29604  [Limited-slip rear differential, Push bar with...
# 29605  [Competition Package (20-inch M alloy wheels, ...
# 29606  [16-inch alloy wheels, Front and rear locking ...
#
#                                            modifications  \
# 0                                                     []
# 1      [Fire-fighting equipment (lights, siren, PA sy...
# 2      [Turner Motorsport Stage 2 93 octane tune, Mac...
# 3      [Borla exhaust system, Bilstein parts in the s...
# 4                                                     []
# ...                                                  ...
# 29602                                   [Tinted windows]
# 29603                                                 []
# 29604  [15-inch aftermarket wheels, Aftermarket head ...
# 29605                                                 []
# 29606  [Old Man Emu 2.5-inch lift kit and shocks, ARB...
#
#                                              known_flaws  \
# 0      [Scuffs on bottom of bumper, Some wear on fron...
# 1      [Some chips and scratches around the exterior,...
# 2      [Chips, scuffs, and scratches around the exter...
# 3      [The seller states that cylinder #6 has "bore ...
# 4      [Rock chips on the front end, Scuffs on the fr...
# ...                                                  ...
# 29602  [Some chips on hood and front bumper (pictured...
# 29603  [There is a discrepancy between the last repor...
# 29604  [Some scratches and stone chips on front end, ...
# 29605  [Some rock chips on front bumper (pictured in ...
# 29606  [Stone chips, scratches, and scuffs around ext...
#
#                                           included_items  ... reserve_status  \
# 0                                                [1 key]  ...        Reserve
# 1      [2 keys, Service record, Red wheels with tires...  ...     No reserve
# 2      [2 keys, Owner’s manuals, Service records, 1 l...  ...        Reserve
# 3                               [1 key, Owner's manuals]  ...     No reserve
# 4                               [2 keys, Owner's manual]  ...        Reserve
# ...                                                  ...  ...            ...
# 29602                                           [2 keys]  ...        Reserve
# 29603                           [2 keys, Owner's manual]  ...     No reserve
# 29604  [2 keys, Owner's manuals, Importation paperwor...  ...        Reserve
# 29605           [2 keys, Owner's manual, Window sticker]  ...        Reserve
# 29606  [2 keys, Owner's manual, Repair manual, Off-ro...  ...     No reserve
#
#                 auction_status highest_bid_value              auction_date  \
# 0      Reserve not met, bid to          $139,000  Mar 12, 2025 8:19 PM UTC
# 1                      Sold to           $10,499  Mar 12, 2025 8:12 PM UTC
# 2                      Sold to           $23,750  Mar 12, 2025 8:11 PM UTC
# 3                      Sold to            $9,500  Mar 12, 2025 8:00 PM UTC
# 4                      Sold to           $42,000  Mar 12, 2025 7:59 PM UTC
# ...                        ...               ...                       ...
# 29602                  Sold to           $59,000     Sep 26, 2022 11:37 PM
# 29603                  Sold to           $15,250     Sep 26, 2022 11:27 PM
# 29604                  Sold to           $27,750     Sep 26, 2022 11:20 PM
# 29605                  Sold to           $56,100     Sep 26, 2022 11:18 PM
# 29606                  Sold to            $8,600     Sep 26, 2022 11:04 PM
#
#       view_count bid_count                                               bids  \
# 0         12,107        31  [$139,000, $138,500, $138,000, $137,500, $137,...
# 1          8,320        18  [$10,499, $10,200, $10,099, $9,999, $9,600, $9...
# 2         13,722        53  [$23,750, $23,500, $23,000, $22,750, $22,500, ...
# 3         11,835        15  [$9,500, $9,100, $9,000, $8,100, $8,000, $7,20...
# 4         12,166        39  [$42,000, $41,000, $40,500, $40,000, $39,750, ...
# ...          ...       ...                                                ...
# 29602      9,136        32  [$59,000, $58,000, $57,000, $56,000, $55,000, ...
# 29603     11,423        15  [$15,250, $15,000, $14,900, $14,800, $14,700, ...
# 29604     11,460        56  [$27,750, $27,500, $26,750, $26,500, $25,750, ...
# 29605     10,021        50  [$56,100, $55,555, $55,000, $54,000, $53,000, ...
# 29606      9,228        30  [$8,600, $8,500, $8,400, $8,200, $8,000, $7,80...
#
#       watcher_count buyer_username seller_username
# 0               0.0            NaN             NaN
# 1               0.0            NaN             NaN
# 2               0.0            NaN             NaN
# 3               0.0            NaN             NaN
# 4               0.0            NaN             NaN
# ...             ...            ...             ...
# 29602           0.0            NaN             NaN
# 29603           0.0            NaN             NaN
# 29604           0.0            NaN             NaN
# 29605           0.0            NaN             NaN
# 29606           0.0            NaN             NaN
#
# [29607 rows x 37 columns]

# %% [markdown]
# ### rename column names

# %%
raw_df.columns = raw_df.columns.str.lower().str.replace(" ","_")
raw_df.columns
# Out:
# Index(['auction_url', 'auction_title', 'auction_subtitle', 'dougs_take',
#        'auction_highlights', 'services', 'auction_equipment', 'modifications',
#        'known_flaws', 'included_items', 'ownership_history', 'seller_notes',
#        'auction_videos', 'make', 'model', 'mileage', 'vin', 'title_status',
#        'location', 'seller', 'engine', 'drivetrain', 'transmission',
#        'body_style', 'exterior_color', 'interior_color', 'seller_type',
#        'reserve_status', 'auction_status', 'highest_bid_value', 'auction_date',
#        'view_count', 'bid_count', 'bids', 'watcher_count', 'buyer_username',
#        'seller_username'],
#       dtype='object')

# %% [markdown]
# ### collect urls of empty auctions

# %%
def get_and_remove_invalid_auctions(df):
    """
    Identifies auctions with invalid auction_status values by checking for key phrases.
    Removes them from the DataFrame and returns their URLs for re-scraping.
    
    Parameters:
        df (pd.DataFrame): The auction DataFrame.
    
    Returns:
        tuple: (cleaned DataFrame, list of auction URLs with invalid statuses)
    """
    # Check for key status indicators (case-insensitive)
    valid_status_mask = (
        df['auction_status'].str.lower().str.contains('sold|reserve not met|cancelled', na=False)
    )
    
    # Get URLs of invalid auctions
    rescrape_urls = df.loc[~valid_status_mask, 'auction_url'].tolist()
    
    # Keep only valid auctions
    clean_auctions_df = df.loc[valid_status_mask].copy()
    
    return clean_auctions_df, rescrape_urls

# %%
df, missing_urls = get_and_remove_invalid_auctions(raw_df)

# %% [markdown]
# ### Convert 'auction_date' to datetime and sort df by auction_date desc

# %%
df['auction_date'] = pd.to_datetime(df['auction_date'], utc=True)
df = df.sort_values('auction_date', ascending=False).reset_index(drop=True)

# %% [markdown]
# ### extract auction id

# %%
def extract_auction_id(url:str)->str:
    return url.strip().split("/")[4]

df['auction_id'] = df['auction_url'].apply(extract_auction_id)

# %% [markdown]
# ### drop duplicates based on auction id

# %%
df = df.drop_duplicates('auction_id', keep='first')

# %% [markdown]
# ### clean 'model' - remove '\nSave'

# %%
df['model'] = df['model'].str.split('\n').str[0].str.strip()

# %% [markdown]
# ### Convert 'mileage' to integer

# %%
import re

def extract_mileage(value):
    if pd.isna(value):
        return None
    match = re.search(r'[\d,]+',value)
    if match:
        return int(match.group(0).replace(',',''))
    return None
df['mileage'] = df['mileage'].apply(extract_mileage)

# %% [markdown]
# ### convert 'highest-bid_value' to float

# %%
df['highest_bid_value'] = df['highest_bid_value'].str.replace('$','').str.replace(',','').astype(float)
df['highest_bid_value']
# Out:
# 0        41500.0
# 1        24000.0
# 2         6300.0
# 3        17750.0
# 4        58500.0
#           ...
# 27503    15000.0
# 27504    21250.0
# 27505    32000.0
# 27506    31500.0
# 27507    35000.0
# Name: highest_bid_value, Length: 27013, dtype: float64

# %% [markdown]
# ### Convert 'bid_count' to integer

# %%
df['bid_count'] = pd.to_numeric(df['bid_count'], errors='coerce')

# %% [markdown]
# ### Convert 'view_count' to integer

# %%
df['view_count'] = df['view_count'].astype(str).str.replace(',', '', regex=False)
df['view_count'] = pd.to_numeric(df['view_count'], errors='coerce').fillna(0).astype(int)

# %% [markdown]
# ### Convert 'watcher_count' to integer

# %%
df['watcher_count'] = df['watcher_count'].astype('str').replace(',','', regex=True)
df['watcher_count'] = pd.to_numeric(df['watcher_count'], errors="coerce").fillna(0).astype(int)

# %% [markdown]
# ### clean 'auction status' - change 'sold to' to 'sold'

# %%
df['auction_status'] = df['auction_status'].str.replace('Sold to','Sold').replace('Reserve not met, bid to', 'Reserve not met')

# %% [markdown]
# ### Create boolean col for reserve status

# %%
df['reserve_met'] = df['auction_status'].str.lower().eq('sold')

# %% [markdown]
# ### remove 'follow' from seller

# %%
df['seller'] = df['seller'].str.split('\n').str[0].str.strip()

# %% [markdown]
# ### clean bids

# %%
def clean_bids(bids_list):
    try:
        return [int(bid.replace("$",'').replace(',','')) for bid in bids_list]
    except Exception as e:
        return []
    
df['bids'] = df['bids'].apply(clean_bids)

# %% [markdown]
# ### Split 'title_status' into 'title_status_clean' and 'title_state'

# %%
df['title_status_cleaned'] = df['title_status'].str.extract(r'^(.*?) \(')
df['title_state'] = df['title_status'].str.extract(r'\((.*?)\)')

# %% [markdown]
# ### Split 'location' into 'city' and 'state'

# %%
def extract_city_state(location):
        if pd.isna(location):
            return None, None
        try:
            parts = location.rsplit(",", 1)
            if len(parts) == 2:
                city = parts[0].strip()
                state = parts[1].strip().split(" ")[0]
                return city,state
            else:
                return parts[0].strip(), None
        except Exception:
            raise
df[['city','state']] = df['location'].apply(extract_city_state).apply(pd.Series)

# %% [markdown]
# ### clean transmission

# %%
def clean_transmission(trans_str):
    if not trans_str or not isinstance(trans_str, str):
        return None, None

    trans_str = trans_str.lower()
    transmission_type = 'Other'
    if 'manual' in trans_str:
        transmission_type = 'Manual' 
    elif 'auto' in trans_str:
        transmission_type = 'Automatic'

    match = re.search(r'(\d+)-speed', trans_str)
    gears = int(match.group(1)) if match else None

    return transmission_type, gears

df['transmission_type'], df['gears'] = zip(*df['transmission'].map(clean_transmission))
df['transmission_type'] = df['transmission_type'].astype('object')

# %% [markdown]
# ### clean drivetrain

# %%
def clean_drivetrain(drive_str):
    if not drive_str or not isinstance(drive_str, str):
        return 'Other'

    drive_str = drive_str.lower()

    if '4wd' in drive_str and 'awd' in drive_str:
        return '4WD/AWD'
    elif 'front' in drive_str:
        return 'FWD'
    elif 'rear' in drive_str:
        return 'RWD'
    elif 'awd' in drive_str or 'all-wheel' in drive_str:
        return 'AWD'
    elif '4wd' in drive_str or 'four-wheel' in drive_str:
        return '4WD'
    else:
        return 'Other'
    
df['drivetrain'] = df['drivetrain'].apply(clean_drivetrain)

# %% [markdown]
#  ### extract bids features

# %%
import numpy as np

def extract_bid_features(bids_list):
    if not bids_list or not isinstance(bids_list, list) or len(bids_list) < 2:
        return pd.Series(
            {
                'max_bid': np.nan,
                'min_bid': np.nan,
                'mean_bid': np.nan,
                'median_bid': np.nan,
                'bid_range': np.nan,
            }
        )

    return pd.Series(
        {
            'max_bid': max(bids_list),
            'min_bid': min(bids_list),
            'mean_bid': np.mean(bids_list),
            'median_bid': np.median(bids_list),
            'bid_range': max(bids_list) - min(bids_list),
        }
    )


features_df = df['bids'].apply(extract_bid_features)
df = df.join(features_df)

# %% [markdown]
# ### add count fields for auction flaws, services, equipment, extra items, highlights,

# %%
def count_list(x):
    return len(x) if isinstance(x, list) else None

df['highlight_count'] = df['auction_highlights'].apply(count_list)
df['equipment_count'] = df['auction_equipment'].apply(count_list)
df['mod_count'] = df['modifications'].apply(count_list)
df['flaw_count'] = df['known_flaws'].apply(count_list)
df['service_count'] = df['services'].apply(count_list)
df['included_items_count'] = df['included_items'].apply(count_list)
df['video_count'] = df['auction_videos'].apply(count_list)

# %%
def extract_manufacture_year(url):
    if pd.isna(url):
        return None
    try:
        return int(url.strip().split("/")[-1].split("-")[0])
    except Exception:
        None

df['manufacture_year'] = df['auction_url'].apply(extract_manufacture_year)

# %%
df.columns
# Out:
# Index(['auction_url', 'auction_title', 'auction_subtitle', 'dougs_take',
#        'auction_highlights', 'services', 'auction_equipment', 'modifications',
#        'known_flaws', 'included_items', 'ownership_history', 'seller_notes',
#        'auction_videos', 'make', 'model', 'mileage', 'vin', 'title_status',
#        'location', 'seller', 'engine', 'drivetrain', 'transmission',
#        'body_style', 'exterior_color', 'interior_color', 'seller_type',
#        'reserve_status', 'auction_status', 'highest_bid_value', 'auction_date',
#        'view_count', 'bid_count', 'bids', 'watcher_count', 'buyer_username',
#        'seller_username', 'auction_id', 'auction_saving_date', 'reserve_met',
#        'title_status_cleaned', 'title_state', 'city', 'state',
#        'transmission_type', 'gears', 'max_bid', 'min_bid', 'mean_bid',
#        'median_bid', 'bid_range', 'highlight_count', 'equipment_count',
#        'mod_count', 'flaw_count', 'service_count', 'included_items_count',
#        'video_count', 'manufacture_year'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27013 entries, 0 to 27507
# Data columns (total 59 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   auction_url           27013 non-null  object
#  1   auction_title         26983 non-null  object
#  2   auction_subtitle      26964 non-null  object
#  3   dougs_take            24391 non-null  object
#  4   auction_highlights    27013 non-null  object
#  5   services              27013 non-null  object
#  6   auction_equipment     25661 non-null  object
#  7   modifications         25661 non-null  object
#  8   known_flaws           27013 non-null  object
#  9   included_items        27013 non-null  object
#  10  ownership_history     26892 non-null  object
#  11  seller_notes          1352 non-null   object
#  12  auction_videos        27013 non-null  object
#  13  make                  27013 non-null  object
#  14  model                 27013 non-null  object
#  15  mileage               26940 non-null  float64
#  16  vin                   27013 non-null  object
#  17  title_status          27013 non-null  object
#  18  location              27013 non-null  object
#  19  seller                27013 non-null  object
#  20  engine                27013 non-null  object
#  21  drivetrain            27013 non-null  object
#  22  transmission          27013 non-null  object
#  23  body_style            27013 non-null  object
#  24  exterior_color        27013 non-null  object
#  25  interior_color        27013 non-null  object
#  26  seller_type           27013 non-null  object
#  27  reserve_status        27013 non-null  object
#  28  auction_status        27013 non-null  object
#  29  highest_bid_value     27013 non-null  float64
#  30  auction_date          27013 non-null  datetime64[ns, UTC]
#  31  view_count            27013 non-null  int64
#  32  bid_count             27013 non-null  int64
#  33  bids                  27013 non-null  object
#  34  watcher_count         27013 non-null  int64
#  35  buyer_username        887 non-null    object
#  36  seller_username       1352 non-null   object
#  37  auction_id            27013 non-null  object
#  38  auction_saving_date   27013 non-null  object
#  39  reserve_met           27013 non-null  bool
#  40  title_status_cleaned  26904 non-null  object
#  41  title_state           26903 non-null  object
#  42  city                  27013 non-null  object
#  43  state                 27012 non-null  object
#  44  transmission_type     27013 non-null  object
#  45  gears                 25707 non-null  float64
#  46  max_bid               26997 non-null  float64
#  47  min_bid               26997 non-null  float64
#  48  mean_bid              26997 non-null  float64
#  49  median_bid            26997 non-null  float64
#  50  bid_range             26997 non-null  float64
#  51  highlight_count       27013 non-null  int64
#  52  equipment_count       25661 non-null  float64
#  53  mod_count             25661 non-null  float64
#  54  flaw_count            27013 non-null  int64
#  55  service_count         27013 non-null  int64
#  56  included_items_count  27013 non-null  int64
#  57  video_count           27013 non-null  int64
#  58  manufacture_year      27005 non-null  float64
# dtypes: bool(1), datetime64[ns, UTC](1), float64(11), int64(8), object(38)
# memory usage: 13.2+ MB

# %%
df[['auction_id','auction_date']]
# Out:
#       auction_id              auction_date
# 0       3646O08y 2025-06-12 20:15:00+00:00
# 1       rMgWezp8 2025-06-12 20:10:00+00:00
# 2       rwA8RZWM 2025-06-12 20:09:00+00:00
# 3       r4Ga6koA 2025-06-12 20:05:00+00:00
# 4       rbpNxPjL 2025-06-12 19:57:00+00:00
# ...          ...                       ...
# 27503   KVGJe7BP 2020-06-16 20:06:00+00:00
# 27504   9elpnQDd 2020-06-16 19:00:00+00:00
# 27505   9nbW8GPJ 2020-06-15 21:02:00+00:00
# 27506   rJnm14vg 2020-06-15 20:04:00+00:00
# 27507   3yBXgzN7 2020-06-15 19:00:00+00:00
#
# [27013 rows x 2 columns]

# %% [markdown]
# ## Save files

# %%
## one json file

df.to_json('test_data.json', orient='records',lines=True)

# %%
## group by auction data then save to json

df['auction_saving_date'] = pd.to_datetime(df['auction_date']).dt.date
for day,group in df.groupby('auction_saving_date'):
    group.drop(columns=['auction_saving_date']).to_json(f'{processed_auctions_path}/{day}.json', orient='records', lines=True)

# %%
## one csv file
df.to_csv('test_data.csv', index=False)
